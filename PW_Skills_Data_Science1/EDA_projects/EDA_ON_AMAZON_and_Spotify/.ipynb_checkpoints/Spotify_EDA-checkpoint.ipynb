# %% [markdown]
# # Exploratory data analysis on spotify data set

# %%
# importing necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("spotify.csv")

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.dtypes
# Out:
# Artist           object
# Track Name       object
# Popularity        int64
# Duration (ms)     int64
# Track ID         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
df.describe(include="all")
# Out:
#        Artist                                         Track Name  Popularity  \
# count     440                                                440  440.000000
# unique    115                                                412         NaN
# top     Drake  Annihilate (Spider-Man: Across the Spider-Vers...         NaN
# freq       20                                                  3         NaN
# mean      NaN                                                NaN   75.736364
# std       NaN                                                NaN    9.886534
# min       NaN                                                NaN   29.000000
# 25%       NaN                                                NaN   70.000000
# 50%       NaN                                                NaN   77.000000
# 75%       NaN                                                NaN   83.000000
# max       NaN                                                NaN   97.000000
#
# ...

# %% [markdown]
# ### 1.Load the dataframe and ensure data quality by checking for missing values and duplicate rows.Handle missing values and remove duplicate rows if necessary.

# %%
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
#  insights >> there is no null values

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# now there is no null values and duplicate values

# %% [markdown]
# ###  2.What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.

# %%
plt.figure(figsize=(10,6))
sns.histplot(x=df['Popularity'],color="red")
plt.title("Distribution among the tracks and popularity")
plt.show()

# %% [markdown]
# ### 3.Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x="Popularity",y="Duration (ms)")
plt.title("Relation between popularity and duration of tracks")
plt.show()

# %% [markdown]
# ###  4.Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.

# %%
highest_nof_tracks  = df["Artist"].value_counts().reset_index()

# %%
plt.figure(figsize=(10,30))
sns.countplot(data = df,y = "Artist" )
plt.show()

# %% [markdown]
# # 5.What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.

# %%
data_sorted = df["Popularity"].sort_values(ascending=True)
df[["Artist","Track Name","Popularity"]].sort_values(by="Popularity")[:5]
# Out:
#              Artist                     Track Name  Popularity
# 207          Pressa  Attachments (feat. Coi Leray)          29
# 231   Justin Bieber                     Intentions          35
# 413  French Montana                Splash Brothers          44
# 225        Lil Baby                  On Me - Remix          47
# 407     Wyclef Jean      911 (feat. Mary J. Blige)          48

# %% [markdown]
# ###  6.Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.

# %%
top_5_avg = df.groupby(["Artist"])["Popularity"].mean().sort_values(ascending = False).reset_index()

# %%
top_5_avg.head()
# Out:
#          Artist  Popularity
# 0         cassö   92.000000
# 1        Trueno   89.000000
# 2  David Guetta   87.000000
# 3  Travis Scott   86.555556
# 4            ¥$   85.100000

# %% [markdown]
# ### 7.For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist

# %%
df[["Artist","Track Name","Popularity"]].sort_values(by="Popularity",ascending=False)[:5]
# Out:
#            Artist                  Track Name  Popularity
# 40    Jack Harlow                 Lovin On Me          97
# 70      21 Savage                      redrum          96
# 260            ¥$                    CARNIVAL          96
# 30   Travis Scott  FE!N (feat. Playboi Carti)          93
# 140         cassö                       Prada          92

# %% [markdown]
# ###  8.Visualize relationships between multiple numerical variables simultaneously using a pair plot.

# %%
sns.pairplot(df)
# plt.title("Relation between multipe numerical  variables")
plt.show()

# %% [markdown]
# ### 9.Does the duration of tracks vary significantly across different artists?  Explore this visually using a box plot or violin plot.

# %%
plt.figure(figsize=(15,20))
sns.boxplot(data=df,y = "Artist",x = "Duration (ms)")
plt.show()

# %% [markdown]
# ### 10.How does the distribution of track popularity vary for different artists?Visualize this using a swarm plot or a violin plot

# %%
plt.figure(figsize=(12,12))
sns.violinplot(data=df,x='Popularity',y='Artist')
# Out:
# <Axes: xlabel='Popularity', ylabel='Artist'>
